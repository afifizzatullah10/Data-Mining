# %% [markdown]
# <a href="https://colab.research.google.com/github/afifizzatullah10/Data-Mining/blob/main/data_mining_exercise_on_data_exploration_v2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

from google.colab import drive
from google.colab import files

# %% [markdown]
# **Data Structures and Commands**

# %% [markdown]
# **Question 1:**

# %%
# Your code here
temperature = [98.2, 97.1, 96.5, 99.7, 100.2, 103.4]
temperature
# Out:
# [98.2, 97.1, 96.5, 99.7, 100.2, 103.4]

# %% [markdown]
# **Question 2:**

# %%
# Your code here

# %% [markdown]
# **Question 3:** Create a numpy array with three rows and four columns using the values below. Print out the whole array.
#
# Row 1: 1, 4, 5, 6
#
# Row 2: 7, 8, 3, 0
#
# Row 3: 7, 8, 3, 0

# %%
# Your code here
my_array = np.array([[1, 4, 5, 6],
                     [7, 8, 3, 0],
                     [7, 8, 3, 0]])
my_array
# Out:
# array([[1, 4, 5, 6],
#        [7, 8, 3, 0],
#        [7, 8, 3, 0]])

# %% [markdown]
# **Question 4:**

# %%
# Your code here
my_array[1, 2]
my_array[2, 3]
# Out:
# np.int64(0)

# %% [markdown]
# **Data Analysis with Pandas**

# %% [markdown]
# **Question 5:** Run the code below to verify you can connect to the data sources.

# %%
# Read the data into a dataframe from the CSV file
file_path = 'https://www.dropbox.com/scl/fi/lle2wyziwywf8kxaq56na/telco_churn.csv?rlkey=kh9571prkkg8uki7mahnwunml&st=br82iz91&dl=1'
data = pd.read_csv(file_path)

data
# Out:
#       CustomerID        Country       State              City  ZipCode  \
# 0     5018-LXQQG  United States  California          Torrance    90505
# 1     4452-QIIEB  United States  California          Glendora    91740
# 2     4176-RELJR  United States  California            Elmira    95625
# 3     5229-PRWKT  United States  California            Lompoc    93437
# 4     4138-NAXED  United States  California       Joshua Tree    92252
# ...          ...            ...         ...               ...      ...
# 6038  8216-AZUUZ  United States  California     San Francisco    94118
# 6039  5006-MXVRN  United States  California             Keyes    95328
# 6040  4804-NCPET  United States  California         Clearlake    95422
# 6041  2878-DHMIN  United States  California        Sacramento    95833
# 6042  7774-OJSXI  United States  California  South Lake Tahoe    96150
#
#                      LatLong   Latitude   Longitude  Gender SeniorCitizen  \
# ...

# %% [markdown]
# **Question 6:** How many rows are there in customer data set? How many columns?

# %%
# Your code here
data.shape
# Out:
# (6043, 31)

# %% [markdown]
# **Question 7:**

# %%
# Your code here
data["MonthlyCharges"].mean()
# Out:
# np.float64(64.54851894754262)

# %% [markdown]
# **Question 8:**

# %%
# Your code here
data['CLTV'].min(), data['CLTV'].min()
# Out:
# (2003, 2003)

# %%
# Your code here
data['CLTV'].max()
# Out:
# 6500

# %% [markdown]
# **Question 9:**

# %%
# Your code here
data.query("MonthlyCharges > 100")[['CustomerID', 'MonthlyCharges', 'ChurnLabel']]
# Out:
#       CustomerID  MonthlyCharges ChurnLabel
# 8     7255-SSFBC          112.25         No
# 10    2522-AHJXR          109.45         No
# 20    9408-HRXRK          105.15         No
# 22    0771-WLCLA          112.95         No
# 25    7134-HBPBS          108.10         No
# ...          ...             ...        ...
# 6017  8033-VCZGH          103.95         No
# 6024  2249-YPRNG          105.85        Yes
# 6037  3761-FLYZI          108.80         No
# 6038  8216-AZUUZ          100.40         No
# 6042  7774-OJSXI          103.45        Yes
#
# [763 rows x 3 columns]

# %% [markdown]
# **Question 10:**

# %%
data.query("TenureMonths > 24 & City == 'Los Angeles'")
# Out:
#       CustomerID        Country       State         City  ZipCode  \
# 35    6467-CHFZW  United States  California  Los Angeles    90028
# 60    6437-UDQJM  United States  California  Los Angeles    90023
# 74    6810-VCAEX  United States  California  Los Angeles    90064
# 153   2359-QWQUL  United States  California  Los Angeles    90058
# 247   5846-ABOBJ  United States  California  Los Angeles    90034
# ...          ...            ...         ...          ...      ...
# 5706  4822-LPTYJ  United States  California  Los Angeles    90021
# 5885  0337-CNPZE  United States  California  Los Angeles    90033
# 5909  4737-AQCPU  United States  California  Los Angeles    90022
# 5919  9888-ZCUMM  United States  California  Los Angeles    90018
# 6037  3761-FLYZI  United States  California  Los Angeles    90011
#
#                      LatLong   Latitude   Longitude  Gender SeniorCitizen  \
# 35    34.099869, -118.326843  34.099869 -118.326843    Male            No
# ...

# %%
# Your code here
data.query("TenureMonths > 24 & City == 'Los Angeles'")[['CustomerID', 'City', 'TenureMonths', 'ChurnLabel', 'CLTV']]
# Out:
#       CustomerID         City  TenureMonths ChurnLabel  CLTV
# 35    6467-CHFZW  Los Angeles            47        Yes  5789
# 60    6437-UDQJM  Los Angeles            72         No  4999
# 74    6810-VCAEX  Los Angeles            47         No  4670
# 153   2359-QWQUL  Los Angeles            39        Yes  2371
# 247   5846-ABOBJ  Los Angeles            71         No  4766
# ...          ...          ...           ...        ...   ...
# 5706  4822-LPTYJ  Los Angeles            72         No  4655
# 5885  0337-CNPZE  Los Angeles            41        Yes  5383
# 5909  4737-AQCPU  Los Angeles            72         No  4658
# 5919  9888-ZCUMM  Los Angeles            64         No  4120
# 6037  3761-FLYZI  Los Angeles            65         No  5225
#
# [139 rows x 5 columns]

# %% [markdown]
# **Question 11:**

# %%
# Your code here
city_counts = data.groupby('City')['CustomerID'].count()
city_counts
# Out:
# City
# Acampo          4
# Acton           4
# Adelanto        4
# Adin            4
# Agoura Hills    4
#                ..
# Yreka           4
# Yuba City       8
# Yucaipa         4
# Yucca Valley    3
# Zenia           4
# Name: CustomerID, Length: 1129, dtype: int64

# %%
city_counts = data.groupby('City').agg(NumberOfCustomers=('CustomerID', 'count'))
city_counts
# Out:
#               NumberOfCustomers
# City
# Acampo                        4
# Acton                         4
# Adelanto                      4
# Adin                          4
# Agoura Hills                  4
# ...                         ...
# Yreka                         4
# Yuba City                     8
# Yucaipa                       4
# Yucca Valley                  3
# Zenia                         4
#
# [1129 rows x 1 columns]

# %% [markdown]
# **Question 12:**

# %%
# Your code here
city_counts.sort_values(by='NumberOfCustomers', ascending=False)
# Out:
#                NumberOfCustomers
# City
# Los Angeles                  273
# San Diego                    131
# San Jose                      95
# San Francisco                 93
# Sacramento                    91
# ...                          ...
# Crockett                       1
# Santa Clarita                  1
# Squaw Valley                   1
# Jamestown                      1
# Leggett                        1
#
# [1129 rows x 1 columns]

# %% [markdown]
# **Question 13:** List all the columns and their data types from telco_churn

# %%
# Your code here
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6043 entries, 0 to 6042
# Data columns (total 31 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   CustomerID        6043 non-null   object
#  1   Country           6043 non-null   object
#  2   State             6043 non-null   object
#  3   City              6043 non-null   object
#  4   ZipCode           6043 non-null   int64
#  5   LatLong           6043 non-null   object
#  6   Latitude          6043 non-null   float64
#  7   Longitude         6043 non-null   float64
#  8   Gender            6043 non-null   object
#  9   SeniorCitizen     6043 non-null   object
#  10  Partner           6043 non-null   object
#  11  Dependents        6043 non-null   object
#  12  TenureMonths      6043 non-null   int64
#  13  PhoneService      6043 non-null   object
#  14  MultipleLines     6043 non-null   object
#  15  InternetService   6043 non-null   object
# ...

# %% [markdown]
# **Question 14:**

# %%
# Your code here

# %%
# Assuming 'df' is the name of your pandas DataFrame
# Replace 'your_dataframe.csv' with the desired filename

# Save the DataFrame to a CSV file
data.to_csv('telco_churn_data.csv', index=False)

# Download the file
files.download('telco_churn_data.csv')

# %% [markdown]
# **Click File -> Download -> Download .ipynb** and upload your progress on this exercise to today's submission
